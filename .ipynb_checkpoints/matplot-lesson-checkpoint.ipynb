# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3], [1,2,3])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.figure(figsize = (1000, 12))
plt.show()

# %%
plt.subplot(1, 1, 1)
plt.plot([1,2,3], [1,2,3])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.figure(figsize = (1000, 12))
# plt.show()

plt.subplot(2, 1, 2)
plt.plot([2,2,5], [1,2,3])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.figure(figsize = (1000, 12))
plt.show()
